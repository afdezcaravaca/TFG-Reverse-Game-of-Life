# %% [markdown]
# ###  Modelo que implementa el GoL
#
# Sin hacer caso a mis tutores, voy a seguir el capitulo 12 del libro "Hands on Machine Learning with Scikit-Learn Keras y TensorFlow",
# y con ayuda de ChatGPT, vamos a intentar crear una "Custom Layer" que implemente el GoL. He leido el cap y creo haberme enterado,
# lo cual me ha motivado a hacer esto, pues sería el aproach correcto del TFG. Independientemente de esto, el modelo de referencia
# sigue siendo el mismo, puesto que solo voy a incorporar la capa.
#
# #### Muestra de que entiendo qué está pasando:
#
# Nosotros queremos crear una capa que no está definida por defecto en TensorFlow o en Keras, puesto que queremos incorporar una capa que juegue al GoL.
# En consecuencia, tenemos que estudiar cómo crear esta layer y, lo que és más importante, estudiar cómo implementa en el modelo. Para la implementación se usan APIs
# de TensorFlow y Keras, por lo que no hay que rallarse, tan solo hay que usar los comandos asociados. Para la creación eso si que tiene más fiesta, pero lo importante:
#
# - La capa simplemente implementa el GoL, no realiza predicciones ni nada => No hace falta definir un "build" en esta clase.
# - Vamos a guardar los pesos del modelo, entonces hay que definir un get_config.
#
# Lo más importante, es que no vamos a jugar al GoL clásico puesto que NO es diferenciable. Esta característica es vital para que el modelo pueda aprender => Debemos buscar
# la forma de hacer que el Juego de la Vida (discreto) sea continuo. Como primera propuesta, y atendiendo a que el GoL clasifica los estados en dos clases (1 o 0), vamos a usar
# la función sigmoide. ¿Cómo se hace esto? Implementamos la función sigmoide centrada con respecto al valor de la vecindad.
#
# 1. Condición de supervivencia: si el estado de la célula es x $\approx$ 1, entonces implementamos una función sigmoide centrada en el intervalo [2,3], de tal forma que es no nula en este intervalo y
# nula fuera de este.
#
# $$
#
#  \sigma(x,n) = \frac{x}{1 + e^{+50(n - 3)(n- 2)}}
#
# $$
# Esta definición de la sigmoide la transforma en una gaussiana => Podemos hacer uso de la sigmoide de tensorflow y convertirla en una gaussiana para jugar al GoL. EL Factor 50 es para
# que su forma se más cuadrada:
#
# ![](Sigmoides/SurvivalSigmoid.png)
#
#
# 2. Condición de nacimiento: si el estado de la célula es x $\approx$ 0, entonces implementamos una función sigmoide tal que tenga un maximo en 3, decayendo conforme se aleja de este valor.
# $$
# \sigma(x,n) = \frac{2(1 - x)}{1 + e^{+50(n - 3)^2}}
#
# $$
#
# El factor 2 es para asegurar que la sigmoide alcance el valor 1 y el 50 para adelgazar la función:
#
# ![](Sigmoides/BornSigmoid.png)
#
#
# La ventaja de todo este procedimiento es que solo necesitados tableros finales en los datasets

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras as ks
import random
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization 
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

# 1. Define la semilla
SEED = 42  
 
# 2. Python built-in random
random.seed(SEED)

# 3. NumPy
np.random.seed(SEED)

# 4. TensorFlow
tf.random.set_seed(SEED)

# (Opcional) Para TensorFlow más determinismo en operaciones GPU:
os.environ['TF_DETERMINISTIC_OPS'] = '1'

path = "../Datos"
datos = []
for dirnames,_,filenames in os.walk(path):
    for filename in filenames:
        if filename.endswith('.xlsx'):
            datos.append(os.path.join(dirnames,filename))

print(datos)
# Out:
# ['../Datos\\test.xlsx', '../Datos\\train.xlsx']

# %% [markdown]
# **1. Funciones de las métricas:**

# %%
# ---------------- Métricas  ----------------
def Accuracy(y_true, y_pred):
    y_pred_rounded = K.round(K.clip(y_pred, 0, 1))
    correct = K.equal(y_true, y_pred_rounded)
    return K.mean(K.cast(correct, K.floatx()))

def Precision(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(y_true * y_pred_pos)
    predicted_positives = K.sum(y_pred_pos)
    return tp / (predicted_positives + K.epsilon())

def Specificity(y_true, y_pred):
    y_pred_neg = 1 - K.round(K.clip(y_pred, 0, 1))
    y_true_neg = 1 - y_true
    tn = K.sum(y_true_neg * y_pred_neg)
    possible_negatives = K.sum(y_true_neg)
    return tn / (possible_negatives + K.epsilon())

def Recall(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(y_true * y_pred_pos)
    possible_positives = K.sum(y_true)
    return tp / (possible_positives + K.epsilon())

def F1_score(y_true, y_pred):
    prec = Precision(y_true, y_pred)
    rec = Recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec + K.epsilon())

def Hamming_loss(y_true, y_pred):
    mismatches = K.not_equal(K.round(K.clip(y_pred, 0, 1)), y_true)
    return K.mean(K.cast(mismatches, K.floatx()))

# %% [markdown]
# **2. Creamos la capa del GoL y el modelo:**

# %%
# Capa diferenciable del Game of Life
class DifferentiableGoL(tf.keras.layers.Layer):
    def __init__(self, steps=1, name=None):
        super().__init__(name=name)
        self.steps = steps
        kernel = [[1, 1, 1],
                  [1, 0, 1],
                  [1, 1, 1]]
        self.kernel = tf.constant(kernel, dtype=tf.float32)
        self.kernel = tf.reshape(self.kernel, [3, 3, 1, 1])  # para tf.nn.conv2d

    def call(self, x):
        for _ in range(self.steps):
            neighbors = tf.nn.conv2d(x, self.kernel, strides=1, padding='SAME')
            survive = x * tf.sigmoid(-50*((neighbors - 2) * (neighbors - 3))) # Condición de supervivencia
            born = (1 - x)* 2 * tf.sigmoid(-50*(neighbors - 3) ** 2) # Condición de nacimiento
            x = tf.clip_by_value(survive + born, 0, 1)
        return x
    
    def get_config(self):
        config = super().get_config()
        config.update({"steps": self.steps})
        return config

# Constructor del modelo
def create_gol_model(n_hidden_convs=2, n_hidden_filters=128, kernel_size=5, steps=1):
    """
    Crea un modelo CNN para Reverse Game of Life con capa diferenciable GoL.

    Inputs:
        n_hidden_convs: Número de capas convolucionales intermedias
        n_hidden_filters: Número de filtros por capa
        kernel_size: Tamaño del kernel convolucional
        steps: Número de pasos del GoL (equivalente a delta)

    Outputs:
        Un modelo tf.keras.Model compilado listo para entrenar
    """
   
    input_final = Input(shape=(20, 20, 1), name='input_final')

    x = Conv2D(n_hidden_filters, kernel_size, padding='same', activation='relu')(input_final)
    x = BatchNormalization()(x)

    for _ in range(n_hidden_convs):
        x = Conv2D(n_hidden_filters, kernel_size, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)

    predicted_init = Conv2D(1, kernel_size, padding='same', activation='sigmoid',
                            name='predicted_init')(x)

    predicted_final = DifferentiableGoL(steps=steps, name='predicted_final')(predicted_init)

    model = Model(inputs=input_final, outputs=[predicted_final, predicted_init], name='GoL_Model')

    model.compile(
        optimizer='adam',
        loss={'predicted_final': 'binary_crossentropy'},
        metrics= {'predicted_final': [Accuracy, Precision, Specificity, Recall, F1_score, Hamming_loss]})

    return model

# %% [markdown]
# **3. Cargamos los datos:**

# %%
# Cargo los datos:
train = pd.read_excel(datos[1], sheet_name = 'train', header = 0)

# Creo una lista con los nombres de los headers de los tableros:
stops = [f'stop.{i}' for i in range(1,401)]

# %% [markdown]
# **4. Entrenamiento del Modelo:**

# %%
# Entrenamiento del modelo delta = 1. Se aplica un bucle para permitir entrenar otros modelos.

models = [] # Almacén de modelos (parámetros optimizados)
historial = [] # Almacén de historiales (loss, accurracy)

for i in range(1,2):
    # Obtenemos los datos para cada delta:
    delta_i = train[train['delta'] == i]
    finales_i = np.reshape(delta_i[stops].values, (-1,20,20,1), order='F')
    
    # Entrenamos al modelo
    model = create_gol_model(n_hidden_convs=6, n_hidden_filters=256, kernel_size=5, steps=i)
    es = EarlyStopping(monitor='loss', patience=9, min_delta=0.001)
    history = model.fit(finales_i, {'predicted_final': finales_i}, epochs=50, verbose=1)
    models.append(model)
    historial.append(history)
# Out:
# Epoch 1/50
# 309/309 [==============================] - 50s 158ms/step - loss: 1.5509 - predicted_final_loss: 1.5509 - predicted_final_Accuracy: 0.8262 - predicted_final_Precision: 0.2264 - predicted_final_Specificity: 0.9315 - predicted_final_Recall: 0.1655 - predicted_final_F1_score: 0.1722 - predicted_final_Hamming_loss: 0.1738
# Epoch 2/50
# 309/309 [==============================] - 49s 158ms/step - loss: 0.3285 - predicted_final_loss: 0.3285 - predicted_final_Accuracy: 0.8735 - predicted_final_Precision: 0.5770 - predicted_final_Specificity: 0.9486 - predicted_final_Recall: 0.3979 - predicted_final_F1_score: 0.4547 - predicted_final_Hamming_loss: 0.1265
# Epoch 3/50
# 309/309 [==============================] - 50s 161ms/step - loss: 0.1712 - predicted_final_loss: 0.1712 - predicted_final_Accuracy: 0.9239 - predicted_final_Precision: 0.7693 - predicted_final_Specificity: 0.9694 - predicted_final_Recall: 0.6381 - predicted_final_F1_score: 0.6940 - predicted_final_Hamming_loss: 0.0761
# Epoch 4/50
# 309/309 [==============================] - 50s 161ms/step - loss: 0.1353 - predicted_final_loss: 0.1353 - predicted_final_Accuracy: 0.9446 - predicted_final_Precision: 0.8268 - predicted_final_Specificity: 0.9750 - predicted_final_Recall: 0.7538 - predicted_final_F1_score: 0.7878 - predicted_final_Hamming_loss: 0.0554
# Epoch 5/50
# 309/309 [==============================] - 50s 161ms/step - loss: 0.1162 - predicted_final_loss: 0.1162 - predicted_final_Accuracy: 0.9549 - predicted_final_Precision: 0.8534 - predicted_final_Specificity: 0.9779 - predicted_final_Recall: 0.8110 - predicted_final_F1_score: 0.8312 - predicted_final_Hamming_loss: 0.0451
# Epoch 6/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.1170 - predicted_final_loss: 0.1170 - predicted_final_Accuracy: 0.9542 - predicted_final_Precision: 0.8482 - predicted_final_Specificity: 0.9770 - predicted_final_Recall: 0.8121 - predicted_final_F1_score: 0.8292 - predicted_final_Hamming_loss: 0.0458
# Epoch 7/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.1038 - predicted_final_loss: 0.1038 - predicted_final_Accuracy: 0.9599 - predicted_final_Precision: 0.8658 - predicted_final_Specificity: 0.9795 - predicted_final_Recall: 0.8371 - predicted_final_F1_score: 0.8507 - predicted_final_Hamming_loss: 0.0401
# Epoch 8/50
# 309/309 [==============================] - 53s 171ms/step - loss: 0.0948 - predicted_final_loss: 0.0948 - predicted_final_Accuracy: 0.9637 - predicted_final_Precision: 0.8787 - predicted_final_Specificity: 0.9813 - predicted_final_Recall: 0.8536 - predicted_final_F1_score: 0.8655 - predicted_final_Hamming_loss: 0.0363
# Epoch 9/50
# 309/309 [==============================] - 54s 175ms/step - loss: 0.1047 - predicted_final_loss: 0.1047 - predicted_final_Accuracy: 0.9621 - predicted_final_Precision: 0.8787 - predicted_final_Specificity: 0.9820 - predicted_final_Recall: 0.8376 - predicted_final_F1_score: 0.8565 - predicted_final_Hamming_loss: 0.0379
# Epoch 10/50
# 309/309 [==============================] - 54s 175ms/step - loss: 0.0739 - predicted_final_loss: 0.0739 - predicted_final_Accuracy: 0.9733 - predicted_final_Precision: 0.9100 - predicted_final_Specificity: 0.9859 - predicted_final_Recall: 0.8945 - predicted_final_F1_score: 0.9021 - predicted_final_Hamming_loss: 0.0267
# Epoch 11/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0688 - predicted_final_loss: 0.0688 - predicted_final_Accuracy: 0.9758 - predicted_final_Precision: 0.9173 - predicted_final_Specificity: 0.9869 - predicted_final_Recall: 0.9059 - predicted_final_F1_score: 0.9115 - predicted_final_Hamming_loss: 0.0242
# Epoch 12/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0665 - predicted_final_loss: 0.0665 - predicted_final_Accuracy: 0.9769 - predicted_final_Precision: 0.9213 - predicted_final_Specificity: 0.9876 - predicted_final_Recall: 0.9102 - predicted_final_F1_score: 0.9156 - predicted_final_Hamming_loss: 0.0231
# Epoch 13/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0636 - predicted_final_loss: 0.0636 - predicted_final_Accuracy: 0.9784 - predicted_final_Precision: 0.9260 - predicted_final_Specificity: 0.9883 - predicted_final_Recall: 0.9162 - predicted_final_F1_score: 0.9209 - predicted_final_Hamming_loss: 0.0216
# Epoch 14/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0610 - predicted_final_loss: 0.0610 - predicted_final_Accuracy: 0.9796 - predicted_final_Precision: 0.9287 - predicted_final_Specificity: 0.9887 - predicted_final_Recall: 0.9225 - predicted_final_F1_score: 0.9255 - predicted_final_Hamming_loss: 0.0204
# Epoch 15/50
# 309/309 [==============================] - 51s 166ms/step - loss: 0.0981 - predicted_final_loss: 0.0981 - predicted_final_Accuracy: 0.9674 - predicted_final_Precision: 0.8967 - predicted_final_Specificity: 0.9847 - predicted_final_Recall: 0.8586 - predicted_final_F1_score: 0.8756 - predicted_final_Hamming_loss: 0.0326
# Epoch 16/50
# 309/309 [==============================] - 51s 167ms/step - loss: 0.0666 - predicted_final_loss: 0.0666 - predicted_final_Accuracy: 0.9768 - predicted_final_Precision: 0.9247 - predicted_final_Specificity: 0.9883 - predicted_final_Recall: 0.9049 - predicted_final_F1_score: 0.9145 - predicted_final_Hamming_loss: 0.0232
# Epoch 17/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0579 - predicted_final_loss: 0.0579 - predicted_final_Accuracy: 0.9814 - predicted_final_Precision: 0.9351 - predicted_final_Specificity: 0.9897 - predicted_final_Recall: 0.9297 - predicted_final_F1_score: 0.9323 - predicted_final_Hamming_loss: 0.0186
# Epoch 18/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0565 - predicted_final_loss: 0.0565 - predicted_final_Accuracy: 0.9820 - predicted_final_Precision: 0.9424 - predicted_final_Specificity: 0.9909 - predicted_final_Recall: 0.9257 - predicted_final_F1_score: 0.9339 - predicted_final_Hamming_loss: 0.0180
# Epoch 19/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0528 - predicted_final_loss: 0.0528 - predicted_final_Accuracy: 0.9842 - predicted_final_Precision: 0.9453 - predicted_final_Specificity: 0.9913 - predicted_final_Recall: 0.9397 - predicted_final_F1_score: 0.9424 - predicted_final_Hamming_loss: 0.0158
# Epoch 20/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0514 - predicted_final_loss: 0.0514 - predicted_final_Accuracy: 0.9849 - predicted_final_Precision: 0.9500 - predicted_final_Specificity: 0.9921 - predicted_final_Recall: 0.9397 - predicted_final_F1_score: 0.9448 - predicted_final_Hamming_loss: 0.0151
# Epoch 21/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0496 - predicted_final_loss: 0.0496 - predicted_final_Accuracy: 0.9859 - predicted_final_Precision: 0.9532 - predicted_final_Specificity: 0.9926 - predicted_final_Recall: 0.9435 - predicted_final_F1_score: 0.9483 - predicted_final_Hamming_loss: 0.0141
# Epoch 22/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0489 - predicted_final_loss: 0.0489 - predicted_final_Accuracy: 0.9859 - predicted_final_Precision: 0.9553 - predicted_final_Specificity: 0.9930 - predicted_final_Recall: 0.9416 - predicted_final_F1_score: 0.9483 - predicted_final_Hamming_loss: 0.0141
# Epoch 23/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.1235 - predicted_final_loss: 0.1235 - predicted_final_Accuracy: 0.9633 - predicted_final_Precision: 0.8874 - predicted_final_Specificity: 0.9842 - predicted_final_Recall: 0.8326 - predicted_final_F1_score: 0.8570 - predicted_final_Hamming_loss: 0.0367
# Epoch 24/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.1026 - predicted_final_loss: 0.1026 - predicted_final_Accuracy: 0.9660 - predicted_final_Precision: 0.9000 - predicted_final_Specificity: 0.9853 - predicted_final_Recall: 0.8448 - predicted_final_F1_score: 0.8701 - predicted_final_Hamming_loss: 0.0340
# Epoch 25/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0940 - predicted_final_loss: 0.0940 - predicted_final_Accuracy: 0.9693 - predicted_final_Precision: 0.9006 - predicted_final_Specificity: 0.9851 - predicted_final_Recall: 0.8709 - predicted_final_F1_score: 0.8844 - predicted_final_Hamming_loss: 0.0307
# Epoch 26/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.0798 - predicted_final_loss: 0.0798 - predicted_final_Accuracy: 0.9734 - predicted_final_Precision: 0.9141 - predicted_final_Specificity: 0.9869 - predicted_final_Recall: 0.8888 - predicted_final_F1_score: 0.9007 - predicted_final_Hamming_loss: 0.0266
# Epoch 27/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.1146 - predicted_final_loss: 0.1146 - predicted_final_Accuracy: 0.9681 - predicted_final_Precision: 0.9067 - predicted_final_Specificity: 0.9863 - predicted_final_Recall: 0.8542 - predicted_final_F1_score: 0.8785 - predicted_final_Hamming_loss: 0.0319
# Epoch 28/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.1096 - predicted_final_loss: 0.1096 - predicted_final_Accuracy: 0.9685 - predicted_final_Precision: 0.9128 - predicted_final_Specificity: 0.9872 - predicted_final_Recall: 0.8520 - predicted_final_F1_score: 0.8807 - predicted_final_Hamming_loss: 0.0315
# Epoch 29/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0733 - predicted_final_loss: 0.0733 - predicted_final_Accuracy: 0.9777 - predicted_final_Precision: 0.9322 - predicted_final_Specificity: 0.9896 - predicted_final_Recall: 0.9034 - predicted_final_F1_score: 0.9173 - predicted_final_Hamming_loss: 0.0223
# Epoch 30/50
# 309/309 [==============================] - 52s 170ms/step - loss: 0.0725 - predicted_final_loss: 0.0725 - predicted_final_Accuracy: 0.9759 - predicted_final_Precision: 0.9248 - predicted_final_Specificity: 0.9884 - predicted_final_Recall: 0.8976 - predicted_final_F1_score: 0.9107 - predicted_final_Hamming_loss: 0.0241
# Epoch 31/50
# 309/309 [==============================] - 52s 170ms/step - loss: 0.0889 - predicted_final_loss: 0.0889 - predicted_final_Accuracy: 0.9704 - predicted_final_Precision: 0.9077 - predicted_final_Specificity: 0.9861 - predicted_final_Recall: 0.8719 - predicted_final_F1_score: 0.8887 - predicted_final_Hamming_loss: 0.0296
# Epoch 32/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.0717 - predicted_final_loss: 0.0717 - predicted_final_Accuracy: 0.9756 - predicted_final_Precision: 0.9285 - predicted_final_Specificity: 0.9892 - predicted_final_Recall: 0.8909 - predicted_final_F1_score: 0.9089 - predicted_final_Hamming_loss: 0.0244
# Epoch 33/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0702 - predicted_final_loss: 0.0702 - predicted_final_Accuracy: 0.9757 - predicted_final_Precision: 0.9238 - predicted_final_Specificity: 0.9884 - predicted_final_Recall: 0.8972 - predicted_final_F1_score: 0.9098 - predicted_final_Hamming_loss: 0.0243
# Epoch 34/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0545 - predicted_final_loss: 0.0545 - predicted_final_Accuracy: 0.9828 - predicted_final_Precision: 0.9438 - predicted_final_Specificity: 0.9912 - predicted_final_Recall: 0.9302 - predicted_final_F1_score: 0.9368 - predicted_final_Hamming_loss: 0.0172
# Epoch 35/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0506 - predicted_final_loss: 0.0506 - predicted_final_Accuracy: 0.9850 - predicted_final_Precision: 0.9519 - predicted_final_Specificity: 0.9925 - predicted_final_Recall: 0.9379 - predicted_final_F1_score: 0.9447 - predicted_final_Hamming_loss: 0.0150
# Epoch 36/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0466 - predicted_final_loss: 0.0466 - predicted_final_Accuracy: 0.9870 - predicted_final_Precision: 0.9585 - predicted_final_Specificity: 0.9935 - predicted_final_Recall: 0.9463 - predicted_final_F1_score: 0.9524 - predicted_final_Hamming_loss: 0.0130
# Epoch 37/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0450 - predicted_final_loss: 0.0450 - predicted_final_Accuracy: 0.9878 - predicted_final_Precision: 0.9607 - predicted_final_Specificity: 0.9938 - predicted_final_Recall: 0.9500 - predicted_final_F1_score: 0.9553 - predicted_final_Hamming_loss: 0.0122
# Epoch 38/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0433 - predicted_final_loss: 0.0433 - predicted_final_Accuracy: 0.9890 - predicted_final_Precision: 0.9657 - predicted_final_Specificity: 0.9946 - predicted_final_Recall: 0.9537 - predicted_final_F1_score: 0.9596 - predicted_final_Hamming_loss: 0.0110
# Epoch 39/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0454 - predicted_final_loss: 0.0454 - predicted_final_Accuracy: 0.9877 - predicted_final_Precision: 0.9579 - predicted_final_Specificity: 0.9934 - predicted_final_Recall: 0.9516 - predicted_final_F1_score: 0.9547 - predicted_final_Hamming_loss: 0.0123
# Epoch 40/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0455 - predicted_final_loss: 0.0455 - predicted_final_Accuracy: 0.9881 - predicted_final_Precision: 0.9592 - predicted_final_Specificity: 0.9935 - predicted_final_Recall: 0.9537 - predicted_final_F1_score: 0.9564 - predicted_final_Hamming_loss: 0.0119
# Epoch 41/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0408 - predicted_final_loss: 0.0408 - predicted_final_Accuracy: 0.9904 - predicted_final_Precision: 0.9695 - predicted_final_Specificity: 0.9952 - predicted_final_Recall: 0.9604 - predicted_final_F1_score: 0.9649 - predicted_final_Hamming_loss: 0.0096
# Epoch 42/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0410 - predicted_final_loss: 0.0410 - predicted_final_Accuracy: 0.9899 - predicted_final_Precision: 0.9687 - predicted_final_Specificity: 0.9951 - predicted_final_Recall: 0.9576 - predicted_final_F1_score: 0.9631 - predicted_final_Hamming_loss: 0.0101
# Epoch 43/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0429 - predicted_final_loss: 0.0429 - predicted_final_Accuracy: 0.9894 - predicted_final_Precision: 0.9672 - predicted_final_Specificity: 0.9949 - predicted_final_Recall: 0.9553 - predicted_final_F1_score: 0.9612 - predicted_final_Hamming_loss: 0.0106
# Epoch 44/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0384 - predicted_final_loss: 0.0384 - predicted_final_Accuracy: 0.9918 - predicted_final_Precision: 0.9736 - predicted_final_Specificity: 0.9958 - predicted_final_Recall: 0.9665 - predicted_final_F1_score: 0.9700 - predicted_final_Hamming_loss: 0.0082
# Epoch 45/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0374 - predicted_final_loss: 0.0374 - predicted_final_Accuracy: 0.9920 - predicted_final_Precision: 0.9748 - predicted_final_Specificity: 0.9960 - predicted_final_Recall: 0.9667 - predicted_final_F1_score: 0.9707 - predicted_final_Hamming_loss: 0.0080
# Epoch 46/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0383 - predicted_final_loss: 0.0383 - predicted_final_Accuracy: 0.9918 - predicted_final_Precision: 0.9738 - predicted_final_Specificity: 0.9959 - predicted_final_Recall: 0.9662 - predicted_final_F1_score: 0.9700 - predicted_final_Hamming_loss: 0.0082
# Epoch 47/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0369 - predicted_final_loss: 0.0369 - predicted_final_Accuracy: 0.9920 - predicted_final_Precision: 0.9712 - predicted_final_Specificity: 0.9954 - predicted_final_Recall: 0.9701 - predicted_final_F1_score: 0.9707 - predicted_final_Hamming_loss: 0.0080
# Epoch 48/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0351 - predicted_final_loss: 0.0351 - predicted_final_Accuracy: 0.9927 - predicted_final_Precision: 0.9750 - predicted_final_Specificity: 0.9960 - predicted_final_Recall: 0.9720 - predicted_final_F1_score: 0.9735 - predicted_final_Hamming_loss: 0.0073
# Epoch 49/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0359 - predicted_final_loss: 0.0359 - predicted_final_Accuracy: 0.9923 - predicted_final_Precision: 0.9733 - predicted_final_Specificity: 0.9958 - predicted_final_Recall: 0.9707 - predicted_final_F1_score: 0.9720 - predicted_final_Hamming_loss: 0.0077
# Epoch 50/50
# 309/309 [==============================] - 52s 168ms/step - loss: 0.0350 - predicted_final_loss: 0.0350 - predicted_final_Accuracy: 0.9929 - predicted_final_Precision: 0.9764 - predicted_final_Specificity: 0.9963 - predicted_final_Recall: 0.9722 - predicted_final_F1_score: 0.9742 - predicted_final_Hamming_loss: 0.0071

# %% [markdown]
# **5. Guardamos todo para reutilizarlo cuando queramos:**  De esta forma no tenemos que ejecutar todo el notebook cada vez.

# %%
# Convertimos el diccionario de historial en un DataFrame:
df_history1 = pd.DataFrame(historial[0].history)

# Guardamos el DataFrame en un archivo Excel:
df_history1.to_excel('../Modelo V2 Reverse/Historial Entrenamiento/historialV2_delta_1.xlsx', index=False)

# Guardamos los modelos
for i, model in enumerate(models):
    model.save(f"../Modelo V2 Reverse/Pesos Modelos/modeloV2_delta_{i+1}", save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Modelo V2 Reverse/Pesos Modelos/modeloV2_delta_1\assets
# INFO:tensorflow:Assets written to: ../Modelo V2 Reverse/Pesos Modelos/modeloV2_delta_1\assets
