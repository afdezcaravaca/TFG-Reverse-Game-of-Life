# %% [markdown]
# ###  Modelo que implementa el GoL
#
# Sin hacer caso a mis tutores, voy a seguir el capitulo 12 del libro "Hands on Machine Learning with Scikit-Learn Keras y TensorFlow",
# y con ayuda de ChatGPT, vamos a intentar crear una "Custom Layer" que implemente el GoL. He leido el cap y creo haberme enterado,
# lo cual me ha motivado a hacer esto, pues sería el aproach correcto del TFG. Independientemente de esto, el modelo de referencia
# sigue siendo el mismo, puesto que solo voy a incorporar la capa.
#
# #### Muestra de que entiendo qué está pasando:
#
# Nosotros queremos crear una capa que no está definida por defecto en TensorFlow o en Keras, puesto que queremos incorporar una capa que juegue al GoL.
# En consecuencia, tenemos que estudiar cómo crear esta layer y, lo que és más importante, estudiar cómo implementa en el modelo. Para la implementación se usan APIs
# de TensorFlow y Keras, por lo que no hay que rallarse, tan solo hay que usar los comandos asociados. Para la creación eso si que tiene más fiesta, pero lo importante:
#
# - La capa simplemente implementa el GoL, no realiza predicciones ni nada => No hace falta definir un "build" en esta clase.
# - Vamos a guardar los pesos del modelo, entonces hay que definir un get_config.
#
# Lo más importante, es que no vamos a jugar al GoL clásico puesto que NO es diferenciable. Esta característica es vital para que el modelo pueda aprender => Debemos buscar
# la forma de hacer que el Juego de la Vida (discreto) sea continuo. Como primera propuesta, y atendiendo a que el GoL clasifica los estados en dos clases (1 o 0), vamos a usar
# la función sigmoide. ¿Cómo se hace esto? Implementamos la función sigmoide centrada con respecto al valor de la vecindad.
#
# 1. Condición de supervivencia: si el estado de la célula es x $\approx$ 1, entonces implementamos una función sigmoide centrada en el intervalo [2,3], de tal forma que es no nula en este intervalo y
# nula fuera de este.
#
# $$
#
#  \sigma(x,n) = \frac{x}{1 + e^{+50(n - 3)(n- 2)}}
#
# $$
# Esta definición de la sigmoide la transforma en una gaussiana => Podemos hacer uso de la sigmoide de tensorflow y convertirla en una gaussiana para jugar al GoL. EL Factor 50 es para
# que su forma se más cuadrada:
#
# ![](Sigmoides/SurvivalSigmoid.png)
#
#
# 2. Condición de nacimiento: si el estado de la célula es x $\approx$ 0, entonces implementamos una función sigmoide tal que tenga un maximo en 3, decayendo conforme se aleja de este valor.
# $$
# \sigma(x,n) = \frac{2(1 - x)}{1 + e^{+50(n - 3)^2}}
#
# $$
#
# El factor 2 es para asegurar que la sigmoide alcance el valor 1 y el 50 para adelgazar la función:
#
# ![](Sigmoides/BornSigmoid.png)
#
#
# La ventaja de todo este procedimiento es que solo necesitados tableros finales en los datasets

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras as ks
import random
import tensorflow as tf
from keras import Input, Model
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization 
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.losses import BinaryFocalCrossentropy

# 1. Define la semilla
SEED = 42  
 
# 2. Python built-in random
random.seed(SEED)

# 3. NumPy
np.random.seed(SEED)

# 4. TensorFlow
tf.random.set_seed(SEED)

# (Opcional) Para TensorFlow más determinismo en operaciones GPU:
os.environ['TF_DETERMINISTIC_OPS'] = '1'

path = "../Datos"
datos = []
for dirnames,_,filenames in os.walk(path):
    for filename in filenames:
        if filename.endswith('.xlsx'):
            datos.append(os.path.join(dirnames,filename))

print(datos)
# Out:
# ['../Datos\\test.xlsx', '../Datos\\train.xlsx']

# %% [markdown]
# **1. Funciones de las métricas:**

# %%
# ---------------- Para el TFG ----------------
def Accuracy(y_true, y_pred):
    y_pred_rounded = K.round(K.clip(y_pred, 0, 1))
    correct = K.equal(y_true, y_pred_rounded)
    return K.mean(K.cast(correct, K.floatx()))

def Precision(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(y_true * y_pred_pos)
    predicted_positives = K.sum(y_pred_pos)
    return tp / (predicted_positives + K.epsilon())

def Specificity(y_true, y_pred):
    y_pred_neg = 1 - K.round(K.clip(y_pred, 0, 1))
    y_true_neg = 1 - y_true
    tn = K.sum(y_true_neg * y_pred_neg)
    possible_negatives = K.sum(y_true_neg)
    return tn / (possible_negatives + K.epsilon())

# ---------------- Extras ----------------
def Recall(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(y_true * y_pred_pos)
    possible_positives = K.sum(y_true)
    return tp / (possible_positives + K.epsilon())

def F1_score(y_true, y_pred):
    prec = Precision(y_true, y_pred)
    rec = Recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec + K.epsilon())

def Hamming_loss(y_true, y_pred):
    mismatches = K.not_equal(K.round(K.clip(y_pred, 0, 1)), y_true)
    return K.mean(K.cast(mismatches, K.floatx()))

# %% [markdown]
# **2. Creamos la capa del GoL y el modelo:**

# %%
# Capa diferenciable del Game of Life
class DifferentiableGoL(tf.keras.layers.Layer):
    def __init__(self, steps=1, name=None):
        super().__init__(name=name)
        self.steps = steps
        kernel = [[1, 1, 1],
                  [1, 0, 1],
                  [1, 1, 1]]
        self.kernel = tf.constant(kernel, dtype=tf.float32)
        self.kernel = tf.reshape(self.kernel, [3, 3, 1, 1])  # para tf.nn.conv2d

    def call(self, x):
        for _ in range(self.steps):
            neighbors = tf.nn.conv2d(x, self.kernel, strides=1, padding='SAME')
            survive = x * tf.sigmoid(-50*((neighbors - 2) * (neighbors - 3))) # Condición de supervivencia
            born = (1 - x)* 2 * tf.sigmoid(-50*(neighbors - 3) ** 2) # Condición de nacimiento
            x = tf.clip_by_value(survive + born, 0, 1)
        return x
    
    def get_config(self):
        config = super().get_config()
        config.update({"steps": self.steps})
        return config

# Constructor del modelo
def create_gol_model(n_hidden_convs=2, n_hidden_filters=128, kernel_size=5, steps=1):
    """
    Crea un modelo CNN para Reverse Game of Life con capa diferenciable GoL.

    Inputs:
        n_hidden_convs: Número de capas convolucionales intermedias
        n_hidden_filters: Número de filtros por capa
        kernel_size: Tamaño del kernel convolucional
        steps: Número de pasos del GoL (equivalente a delta)

    Outputs:
        Un modelo tf.keras.Model compilado listo para entrenar
    """
   
    input_final = Input(shape=(20, 20, 1), name='input_final')

    x = Conv2D(n_hidden_filters, kernel_size, padding='same', activation='relu')(input_final)
    x = BatchNormalization()(x)

    for _ in range(n_hidden_convs):
        x = Conv2D(n_hidden_filters, kernel_size, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)

    predicted_init = Conv2D(1, kernel_size, padding='same', activation='sigmoid',
                            name='predicted_init')(x)

    predicted_final = DifferentiableGoL(steps=steps, name='predicted_final')(predicted_init)

    model = Model(inputs=input_final, outputs=[predicted_final, predicted_init], name='GoL_Model')
    
    focal_loss = BinaryFocalCrossentropy(
        alpha=0.75,      # valor mayor a 0.5 da mayor peso a la clase positiva (1)
        gamma=2,
        from_logits=False)
    
    model.compile(
        optimizer='adam',
        loss={'predicted_final': focal_loss},
        metrics= [Accuracy, Precision, Specificity, Recall, F1_score, Hamming_loss])

    return model

# %% [markdown]
# **3. Cargamos los datos:**

# %%
# Cargo los datos:
train = pd.read_excel(datos[1], sheet_name = 'train', header = 0)

# Creo una lista con los nombres de los headers de los tableros:
stops = [f'stop.{i}' for i in range(1,401)]

# %% [markdown]
# **4. Entrenamiento del Modelo:**

# %%
# Entrenamiento del modelo delta = 1. Se aplica un bucle para permitir entrenar otros modelos.

models = [] # Almacén de modelos (parámetros optimizados)
historial = [] # Almacén de historiales (loss, accurracy)
i=1
for i in range(1,2):
    # Obtenemos los datos para cada delta:
    delta_i = train[train['delta'] == i]
    finales_i = np.reshape(delta_i[stops].values, (-1,20,20,1), order='F')
    
    # Entrenamos al modelo
    model = create_gol_model(n_hidden_convs=6, n_hidden_filters=256, kernel_size=5, steps=i)
    es = EarlyStopping(monitor='loss', patience=9, min_delta=0.001)
    history = model.fit(finales_i, {'predicted_final': finales_i}, epochs=50, verbose=1)
    models.append(model)
    historial.append(history)
# Out:
# Epoch 1/50
# 309/309 [==============================] - 49s 154ms/step - loss: 1.5069 - predicted_final_loss: 1.5069 - predicted_final_Accuracy: 0.8199 - predicted_final_Precision: 0.1831 - predicted_final_Specificity: 0.9336 - predicted_final_Recall: 0.1040 - predicted_final_F1_score: 0.1175 - predicted_final_Hamming_loss: 0.1801 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 2/50
# 309/309 [==============================] - 48s 156ms/step - loss: 0.4968 - predicted_final_loss: 0.4968 - predicted_final_Accuracy: 0.8201 - predicted_final_Precision: 0.2443 - predicted_final_Specificity: 0.9243 - predicted_final_Recall: 0.1602 - predicted_final_F1_score: 0.1662 - predicted_final_Hamming_loss: 0.1799 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 3/50
# 309/309 [==============================] - 48s 157ms/step - loss: 0.1147 - predicted_final_loss: 0.1147 - predicted_final_Accuracy: 0.8601 - predicted_final_Precision: 0.4738 - predicted_final_Specificity: 0.9604 - predicted_final_Recall: 0.2242 - predicted_final_F1_score: 0.2809 - predicted_final_Hamming_loss: 0.1399 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 4/50
# 309/309 [==============================] - 49s 159ms/step - loss: 0.0766 - predicted_final_loss: 0.0766 - predicted_final_Accuracy: 0.8867 - predicted_final_Precision: 0.6760 - predicted_final_Specificity: 0.9752 - predicted_final_Recall: 0.3275 - predicted_final_F1_score: 0.4207 - predicted_final_Hamming_loss: 0.1133 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 5/50
# 309/309 [==============================] - 50s 162ms/step - loss: 0.0597 - predicted_final_loss: 0.0597 - predicted_final_Accuracy: 0.9102 - predicted_final_Precision: 0.7806 - predicted_final_Specificity: 0.9779 - predicted_final_Recall: 0.4852 - predicted_final_F1_score: 0.5832 - predicted_final_Hamming_loss: 0.0898 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 6/50
# 309/309 [==============================] - 50s 163ms/step - loss: 0.0487 - predicted_final_loss: 0.0487 - predicted_final_Accuracy: 0.9279 - predicted_final_Precision: 0.8219 - predicted_final_Specificity: 0.9781 - predicted_final_Recall: 0.6142 - predicted_final_F1_score: 0.6924 - predicted_final_Hamming_loss: 0.0721 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 7/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0513 - predicted_final_loss: 0.0513 - predicted_final_Accuracy: 0.9271 - predicted_final_Precision: 0.8174 - predicted_final_Specificity: 0.9775 - predicted_final_Recall: 0.6108 - predicted_final_F1_score: 0.6824 - predicted_final_Hamming_loss: 0.0729 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 8/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0506 - predicted_final_loss: 0.0506 - predicted_final_Accuracy: 0.9302 - predicted_final_Precision: 0.8180 - predicted_final_Specificity: 0.9768 - predicted_final_Recall: 0.6403 - predicted_final_F1_score: 0.7031 - predicted_final_Hamming_loss: 0.0698 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 9/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0580 - predicted_final_loss: 0.0580 - predicted_final_Accuracy: 0.9201 - predicted_final_Precision: 0.7957 - predicted_final_Specificity: 0.9756 - predicted_final_Recall: 0.5737 - predicted_final_F1_score: 0.6449 - predicted_final_Hamming_loss: 0.0799 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 10/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0442 - predicted_final_loss: 0.0442 - predicted_final_Accuracy: 0.9402 - predicted_final_Precision: 0.8471 - predicted_final_Specificity: 0.9796 - predicted_final_Recall: 0.6955 - predicted_final_F1_score: 0.7498 - predicted_final_Hamming_loss: 0.0598 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 11/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0468 - predicted_final_loss: 0.0468 - predicted_final_Accuracy: 0.9343 - predicted_final_Precision: 0.8352 - predicted_final_Specificity: 0.9789 - predicted_final_Recall: 0.6572 - predicted_final_F1_score: 0.7199 - predicted_final_Hamming_loss: 0.0657 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 12/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0579 - predicted_final_loss: 0.0579 - predicted_final_Accuracy: 0.9293 - predicted_final_Precision: 0.8167 - predicted_final_Specificity: 0.9761 - predicted_final_Recall: 0.6371 - predicted_final_F1_score: 0.6977 - predicted_final_Hamming_loss: 0.0707 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 13/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0389 - predicted_final_loss: 0.0389 - predicted_final_Accuracy: 0.9445 - predicted_final_Precision: 0.8585 - predicted_final_Specificity: 0.9811 - predicted_final_Recall: 0.7164 - predicted_final_F1_score: 0.7687 - predicted_final_Hamming_loss: 0.0555 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 14/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0255 - predicted_final_loss: 0.0255 - predicted_final_Accuracy: 0.9658 - predicted_final_Precision: 0.9038 - predicted_final_Specificity: 0.9856 - predicted_final_Recall: 0.8437 - predicted_final_F1_score: 0.8696 - predicted_final_Hamming_loss: 0.0342 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 15/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0343 - predicted_final_loss: 0.0343 - predicted_final_Accuracy: 0.9557 - predicted_final_Precision: 0.8899 - predicted_final_Specificity: 0.9844 - predicted_final_Recall: 0.7771 - predicted_final_F1_score: 0.8192 - predicted_final_Hamming_loss: 0.0443 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 16/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0275 - predicted_final_loss: 0.0275 - predicted_final_Accuracy: 0.9632 - predicted_final_Precision: 0.9004 - predicted_final_Specificity: 0.9853 - predicted_final_Recall: 0.8257 - predicted_final_F1_score: 0.8561 - predicted_final_Hamming_loss: 0.0368 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 17/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0233 - predicted_final_loss: 0.0233 - predicted_final_Accuracy: 0.9703 - predicted_final_Precision: 0.9155 - predicted_final_Specificity: 0.9874 - predicted_final_Recall: 0.8633 - predicted_final_F1_score: 0.8853 - predicted_final_Hamming_loss: 0.0297 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 18/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0414 - predicted_final_loss: 0.0414 - predicted_final_Accuracy: 0.9546 - predicted_final_Precision: 0.8754 - predicted_final_Specificity: 0.9828 - predicted_final_Recall: 0.7794 - predicted_final_F1_score: 0.8167 - predicted_final_Hamming_loss: 0.0454 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 19/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0817 - predicted_final_loss: 0.0817 - predicted_final_Accuracy: 0.9201 - predicted_final_Precision: 0.7794 - predicted_final_Specificity: 0.9722 - predicted_final_Recall: 0.5931 - predicted_final_F1_score: 0.6576 - predicted_final_Hamming_loss: 0.0799 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 20/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0521 - predicted_final_loss: 0.0521 - predicted_final_Accuracy: 0.9291 - predicted_final_Precision: 0.8357 - predicted_final_Specificity: 0.9790 - predicted_final_Recall: 0.6195 - predicted_final_F1_score: 0.6930 - predicted_final_Hamming_loss: 0.0709 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 21/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0422 - predicted_final_loss: 0.0422 - predicted_final_Accuracy: 0.9414 - predicted_final_Precision: 0.8542 - predicted_final_Specificity: 0.9803 - predicted_final_Recall: 0.7021 - predicted_final_F1_score: 0.7570 - predicted_final_Hamming_loss: 0.0586 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 22/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0350 - predicted_final_loss: 0.0350 - predicted_final_Accuracy: 0.9581 - predicted_final_Precision: 0.8909 - predicted_final_Specificity: 0.9840 - predicted_final_Recall: 0.7978 - predicted_final_F1_score: 0.8343 - predicted_final_Hamming_loss: 0.0419 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 23/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0474 - predicted_final_loss: 0.0474 - predicted_final_Accuracy: 0.9385 - predicted_final_Precision: 0.8367 - predicted_final_Specificity: 0.9788 - predicted_final_Recall: 0.6916 - predicted_final_F1_score: 0.7455 - predicted_final_Hamming_loss: 0.0615 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 24/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0458 - predicted_final_loss: 0.0458 - predicted_final_Accuracy: 0.9435 - predicted_final_Precision: 0.8504 - predicted_final_Specificity: 0.9792 - predicted_final_Recall: 0.7210 - predicted_final_F1_score: 0.7692 - predicted_final_Hamming_loss: 0.0565 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 25/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0501 - predicted_final_loss: 0.0501 - predicted_final_Accuracy: 0.9414 - predicted_final_Precision: 0.8544 - predicted_final_Specificity: 0.9802 - predicted_final_Recall: 0.7021 - predicted_final_F1_score: 0.7612 - predicted_final_Hamming_loss: 0.0586 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 26/50
# 309/309 [==============================] - 51s 164ms/step - loss: 0.0179 - predicted_final_loss: 0.0179 - predicted_final_Accuracy: 0.9764 - predicted_final_Precision: 0.9377 - predicted_final_Specificity: 0.9906 - predicted_final_Recall: 0.8892 - predicted_final_F1_score: 0.9119 - predicted_final_Hamming_loss: 0.0236 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 27/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0159 - predicted_final_loss: 0.0159 - predicted_final_Accuracy: 0.9798 - predicted_final_Precision: 0.9475 - predicted_final_Specificity: 0.9920 - predicted_final_Recall: 0.9041 - predicted_final_F1_score: 0.9243 - predicted_final_Hamming_loss: 0.0202 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 28/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0132 - predicted_final_loss: 0.0132 - predicted_final_Accuracy: 0.9847 - predicted_final_Precision: 0.9577 - predicted_final_Specificity: 0.9935 - predicted_final_Recall: 0.9304 - predicted_final_F1_score: 0.9436 - predicted_final_Hamming_loss: 0.0153 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 29/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0122 - predicted_final_loss: 0.0122 - predicted_final_Accuracy: 0.9863 - predicted_final_Precision: 0.9619 - predicted_final_Specificity: 0.9941 - predicted_final_Recall: 0.9381 - predicted_final_F1_score: 0.9497 - predicted_final_Hamming_loss: 0.0137 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 30/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0115 - predicted_final_loss: 0.0115 - predicted_final_Accuracy: 0.9871 - predicted_final_Precision: 0.9645 - predicted_final_Specificity: 0.9945 - predicted_final_Recall: 0.9415 - predicted_final_F1_score: 0.9526 - predicted_final_Hamming_loss: 0.0129 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 31/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0119 - predicted_final_loss: 0.0119 - predicted_final_Accuracy: 0.9862 - predicted_final_Precision: 0.9637 - predicted_final_Specificity: 0.9944 - predicted_final_Recall: 0.9354 - predicted_final_F1_score: 0.9486 - predicted_final_Hamming_loss: 0.0138 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 32/50
# 309/309 [==============================] - 51s 166ms/step - loss: 0.0099 - predicted_final_loss: 0.0099 - predicted_final_Accuracy: 0.9894 - predicted_final_Precision: 0.9699 - predicted_final_Specificity: 0.9953 - predicted_final_Recall: 0.9534 - predicted_final_F1_score: 0.9614 - predicted_final_Hamming_loss: 0.0106 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 33/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0097 - predicted_final_loss: 0.0097 - predicted_final_Accuracy: 0.9896 - predicted_final_Precision: 0.9707 - predicted_final_Specificity: 0.9954 - predicted_final_Recall: 0.9542 - predicted_final_F1_score: 0.9622 - predicted_final_Hamming_loss: 0.0104 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 34/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0091 - predicted_final_loss: 0.0091 - predicted_final_Accuracy: 0.9906 - predicted_final_Precision: 0.9728 - predicted_final_Specificity: 0.9957 - predicted_final_Recall: 0.9589 - predicted_final_F1_score: 0.9657 - predicted_final_Hamming_loss: 0.0094 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 35/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0894 - predicted_final_loss: 0.0894 - predicted_final_Accuracy: 0.9329 - predicted_final_Precision: 0.8238 - predicted_final_Specificity: 0.9756 - predicted_final_Recall: 0.6647 - predicted_final_F1_score: 0.7222 - predicted_final_Hamming_loss: 0.0671 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 36/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0323 - predicted_final_loss: 0.0323 - predicted_final_Accuracy: 0.9505 - predicted_final_Precision: 0.8854 - predicted_final_Specificity: 0.9850 - predicted_final_Recall: 0.7363 - predicted_final_F1_score: 0.7992 - predicted_final_Hamming_loss: 0.0495 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 37/50
# 309/309 [==============================] - 51s 166ms/step - loss: 0.0183 - predicted_final_loss: 0.0183 - predicted_final_Accuracy: 0.9763 - predicted_final_Precision: 0.9380 - predicted_final_Specificity: 0.9907 - predicted_final_Recall: 0.8875 - predicted_final_F1_score: 0.9111 - predicted_final_Hamming_loss: 0.0237 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 38/50
# 309/309 [==============================] - 51s 166ms/step - loss: 0.0151 - predicted_final_loss: 0.0151 - predicted_final_Accuracy: 0.9824 - predicted_final_Precision: 0.9503 - predicted_final_Specificity: 0.9924 - predicted_final_Recall: 0.9208 - predicted_final_F1_score: 0.9349 - predicted_final_Hamming_loss: 0.0176 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 39/50
# 309/309 [==============================] - 51s 165ms/step - loss: 0.0149 - predicted_final_loss: 0.0149 - predicted_final_Accuracy: 0.9823 - predicted_final_Precision: 0.9519 - predicted_final_Specificity: 0.9927 - predicted_final_Recall: 0.9184 - predicted_final_F1_score: 0.9341 - predicted_final_Hamming_loss: 0.0177 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 40/50
# 309/309 [==============================] - 51s 166ms/step - loss: 0.0138 - predicted_final_loss: 0.0138 - predicted_final_Accuracy: 0.9849 - predicted_final_Precision: 0.9573 - predicted_final_Specificity: 0.9934 - predicted_final_Recall: 0.9323 - predicted_final_F1_score: 0.9443 - predicted_final_Hamming_loss: 0.0151 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 41/50
# 309/309 [==============================] - 52s 167ms/step - loss: 0.0110 - predicted_final_loss: 0.0110 - predicted_final_Accuracy: 0.9882 - predicted_final_Precision: 0.9649 - predicted_final_Specificity: 0.9945 - predicted_final_Recall: 0.9491 - predicted_final_F1_score: 0.9568 - predicted_final_Hamming_loss: 0.0118 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 42/50
# 309/309 [==============================] - 52s 169ms/step - loss: 0.0125 - predicted_final_loss: 0.0125 - predicted_final_Accuracy: 0.9856 - predicted_final_Precision: 0.9624 - predicted_final_Specificity: 0.9943 - predicted_final_Recall: 0.9311 - predicted_final_F1_score: 0.9451 - predicted_final_Hamming_loss: 0.0144 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 43/50
# 309/309 [==============================] - 53s 171ms/step - loss: 0.0114 - predicted_final_loss: 0.0114 - predicted_final_Accuracy: 0.9871 - predicted_final_Precision: 0.9637 - predicted_final_Specificity: 0.9944 - predicted_final_Recall: 0.9419 - predicted_final_F1_score: 0.9517 - predicted_final_Hamming_loss: 0.0129 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 44/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.0095 - predicted_final_loss: 0.0095 - predicted_final_Accuracy: 0.9899 - predicted_final_Precision: 0.9705 - predicted_final_Specificity: 0.9954 - predicted_final_Recall: 0.9562 - predicted_final_F1_score: 0.9630 - predicted_final_Hamming_loss: 0.0101 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 45/50
# 309/309 [==============================] - 53s 170ms/step - loss: 0.0089 - predicted_final_loss: 0.0089 - predicted_final_Accuracy: 0.9911 - predicted_final_Precision: 0.9733 - predicted_final_Specificity: 0.9958 - predicted_final_Recall: 0.9622 - predicted_final_F1_score: 0.9676 - predicted_final_Hamming_loss: 0.0089 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 46/50
# 309/309 [==============================] - 53s 171ms/step - loss: 0.0088 - predicted_final_loss: 0.0088 - predicted_final_Accuracy: 0.9914 - predicted_final_Precision: 0.9729 - predicted_final_Specificity: 0.9957 - predicted_final_Recall: 0.9647 - predicted_final_F1_score: 0.9688 - predicted_final_Hamming_loss: 0.0086 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 47/50
# 309/309 [==============================] - 53s 171ms/step - loss: 0.0094 - predicted_final_loss: 0.0094 - predicted_final_Accuracy: 0.9909 - predicted_final_Precision: 0.9710 - predicted_final_Specificity: 0.9954 - predicted_final_Recall: 0.9631 - predicted_final_F1_score: 0.9669 - predicted_final_Hamming_loss: 0.0091 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 48/50
# 309/309 [==============================] - 53s 171ms/step - loss: 0.0104 - predicted_final_loss: 0.0104 - predicted_final_Accuracy: 0.9885 - predicted_final_Precision: 0.9691 - predicted_final_Specificity: 0.9952 - predicted_final_Recall: 0.9466 - predicted_final_F1_score: 0.9569 - predicted_final_Hamming_loss: 0.0115 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 49/50
# 309/309 [==============================] - 54s 173ms/step - loss: 0.0083 - predicted_final_loss: 0.0083 - predicted_final_Accuracy: 0.9921 - predicted_final_Precision: 0.9749 - predicted_final_Specificity: 0.9960 - predicted_final_Recall: 0.9678 - predicted_final_F1_score: 0.9713 - predicted_final_Hamming_loss: 0.0079 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00
# Epoch 50/50
# 309/309 [==============================] - 53s 173ms/step - loss: 0.0095 - predicted_final_loss: 0.0095 - predicted_final_Accuracy: 0.9914 - predicted_final_Precision: 0.9736 - predicted_final_Specificity: 0.9959 - predicted_final_Recall: 0.9639 - predicted_final_F1_score: 0.9687 - predicted_final_Hamming_loss: 0.0086 - predicted_init_Accuracy: 0.0000e+00 - predicted_init_Precision: 0.0000e+00 - predicted_init_Specificity: 0.0000e+00 - predicted_init_Recall: 0.0000e+00 - predicted_init_F1_score: 0.0000e+00 - predicted_init_Hamming_loss: 0.0000e+00

# %% [markdown]
# **5. Guardamos todo para reutilizarlo cuando queramos:**  De esta forma no tenemos que ejecutar todo el notebook cada vez.

# %%
# Convertimos el diccionario de historial en un DataFrame:
df_history1 = pd.DataFrame(historial[0].history)

# Guardamos el DataFrame en un archivo Excel:
df_history1.to_excel('../Modelo V2 Reverse FBCE/Historial Entrenamiento/historialFBCE_delta_1.xlsx', index=False)

# Guardamos los modelos
for i, model in enumerate(models):
    model.save(f"../Modelo V2 Reverse FBCE/Pesos Modelos/modeloFBCE_delta_{i+1}", save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Modelo V2 Reverse FBCE/Pesos Modelos/modeloFBCE_delta_1\assets
# INFO:tensorflow:Assets written to: ../Modelo V2 Reverse FBCE/Pesos Modelos/modeloFBCE_delta_1\assets
